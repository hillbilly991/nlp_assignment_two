# %%
# !pip install spaczz
# !pip install apyori
# !pip install mlxtend
# !pip install textblob
# Out:
# Requirement already satisfied: spaczz in /Users/tomhill/anaconda3/lib/python3.11/site-packages (0.6.1)
# Requirement already satisfied: catalogue in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spaczz) (2.0.10)
# Requirement already satisfied: rapidfuzz>=1.0.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spaczz) (3.9.4)
# Requirement already satisfied: regex>=2020.6.8 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spaczz) (2023.10.3)
# Requirement already satisfied: spacy<4.0,>=3.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spaczz) (3.7.5)
# Requirement already satisfied: srsly in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spaczz) (2.4.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (1.1.3)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (2.5.3)
# Requirement already satisfied: jinja2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (3.1.3)
# Requirement already satisfied: setuptools in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (70.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from spacy<4.0,>=3.0->spaczz) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->spaczz) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->spaczz) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->spaczz) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0,>=3.0->spaczz) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spaczz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spaczz) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spaczz) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0,>=3.0->spaczz) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0,>=3.0->spaczz) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0,>=3.0->spaczz) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0,>=3.0->spaczz) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->spaczz) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0,>=3.0->spaczz) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<4.0,>=3.0->spaczz) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0,>=3.0->spaczz) (1.2.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: apyori in /Users/tomhill/anaconda3/lib/python3.11/site-packages (1.1.2)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: mlxtend in /Users/tomhill/anaconda3/lib/python3.11/site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.26.3)
# Requirement already satisfied: pandas>=0.24.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from mlxtend) (2.1.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from mlxtend) (3.8.0)
# Requirement already satisfied: joblib>=0.13.2 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/tomhill/anaconda3/lib/python3.11/site-packages (from nltk>=3.8->textblob) (4.65.0)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.3/626.3 kB 7.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import re
import spacy
import copy
import pandas as pd
from spaczz.matcher import FuzzyMatcher
import nltk
import string
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # 1. Extract Relevant Information

# %% [markdown]
# ## Crawl Reviews
# Here we are just going to ingest the data rawly but put it into a structure where we know which product the review belongs to

# %%
def read_all_files_in_folder(directory):
    dataframes = []
    for root, directories, files in os.walk(directory):
        for filename in files:
            file_path = os.path.join(root, filename)
            df = pd.read_table(file_path, on_bad_lines='skip', encoding='cp1252', header=None)
            product_name = filename.replace('.txt', '')
            df['product'] = product_name
            dataframes.append(df)
    
    combined_df = pd.concat(dataframes, ignore_index=True)
    combined_df.columns = ['line', 'product'] 
    combined_df = combined_df[['product', 'line']]
    
    return combined_df

df_raw_product_lines = read_all_files_in_folder("./Data")
df_raw_product_lines.describe()
# Out:
#                                           product   line
# count                                       10920  10920
# unique                                         17  10531
# top     Creative Labs Nomad Jukebox Zen Xtra 40GB    [t]
# freq                                         1811    325

# %% [markdown]
# ## Parse Reviews
# Here we just want to parse the reviews from each of the products. Currently there are tags such as [t], feature[+/-] - these aren't needed

# %%
def parse_reviews(df):
    df['annotated_labels'] = df['line'].apply(lambda x: ' '.join(re.findall(r'(.*)##', x)))
    df['review'] = df['line'].apply(lambda x: ' '.join(re.findall(r'##(.*)', x)))
    df['review'] = df.apply(
        lambda row: ' '.join(re.findall(r'\[t\](.*)', row['line'])) if row['review'] == '' else row['review'],
        axis=1
    )
    return df

df_product_reviews = parse_reviews(df_raw_product_lines)
df_product_reviews[['product', 'line', 'annotated_labels', 'review']]
# Out:
#                      product  \
# 0                 Nokia 6610
# 1                 Nokia 6610
# 2                 Nokia 6610
# 3                 Nokia 6610
# 4                 Nokia 6610
# ...                      ...
# 10915  Canon PowerShot SD500
# 10916  Canon PowerShot SD500
# 10917  Canon PowerShot SD500
# 10918  Canon PowerShot SD500
# 10919  Canon PowerShot SD500
#
#                                                     line  \
# 0               [t]excellent phone , excellent service .
# 1      ##i am a business user who heavily depend on m...
# 2      phone[+3], work[+2]##there is much which has b...
# 3      ##just double check with customer service to e...
# 4      at&t customer service[-2]##after several years...
# ...                                                  ...
# 10915  automatic shutter[-3]##There were many times w...
# 10916  ##It seems you have to double click some of th...
# 10917  ##Huh? I missed out on lots of photos and lots...
# 10918  controls[-1]##The controls are hard to manipul...
# 10919  LCD[-2]##The LCD screen is too small since the...
#
#                 annotated_labels  \
# 0
# 1
# 2            phone[+3], work[+2]
# 3
# 4      at&t customer service[-2]
# ...                          ...
# 10915      automatic shutter[-3]
# 10916
# 10917
# 10918               controls[-1]
# 10919                    LCD[-2]
#
#                                                   review
# 0                  excellent phone , excellent service .
# 1      i am a business user who heavily depend on mob...
# 2      there is much which has been said in other rev...
# 3      just double check with customer service to ens...
# 4      after several years of torture in the hands of...
# ...                                                  ...
# 10915  There were many times when I clicked the autom...
# 10916  It seems you have to double click some of the ...
# 10917  Huh? I missed out on lots of photos and lots a...
# 10918  The controls are hard to manipulate, especiall...
# 10919  The LCD screen is too small since there are so...
#
# [10920 rows x 4 columns]

# %% [markdown]
# ### Preprocess
# There are a number of steps we need to take when preprocessing the data:
# 1. tokenize the reviews so that only wordsWe need to label the PoS of each of the sentences in order to be able to begin to prune down the reviews and start to comprehend which phrases are the features and which words are the opinions

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package wordnet to /Users/tomhill/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/tomhill/nltk_data...
# True

# %%
class Preprocess:
    def __init__(self):
        self.stop_words = set(nltk.corpus.stopwords.words('english'))
        
    def main(self, reviews):
        tokenize_reviews = self.lower_tokenize_reviews(reviews)
        remove_punctuation_reviews = self.remove_punctuation_reviews(tokenize_reviews)
        remove_stopwords_reviews = self.remove_stopwords_reviews(remove_punctuation_reviews)
        pos_tag_reviews = self.pos_tag_reviews(remove_stopwords_reviews)
        lemmatize_reviews = self.lemmatize_reviews(pos_tag_reviews)

        return lemmatize_reviews
    
    def perform_fuzzy_matching(self, reviews):
        """
        This actually isn't fuzzy matching.... If we were to integrate it we'd need to do it against
        a list of already established words
        """
        return reviews.apply(lambda x: str(TextBlob(x).correct()))
        
    def lower_tokenize_reviews(self, reviews):
        return reviews.apply(lambda x: nltk.word_tokenize(x.lower()))
        
    def remove_punctuation_reviews(self, reviews):
        return reviews.apply(lambda tokens: [
            word.translate(str.maketrans('', '', string.punctuation))
            for word in tokens
        ])
                             
    def remove_stopwords_reviews(self, reviews):
        return reviews.apply(lambda tokens: [word for word in tokens if word not in self.stop_words])

    def pos_tag_reviews(self, reviews):
        return reviews.apply(lambda x: nltk.pos_tag(x))
        
    # change
    def get_wordnet_pos(self, tag):
        if tag.startswith('J'):
            return wordnet.ADJ
        elif tag.startswith('V'):
            return wordnet.VERB
        elif tag.startswith('N'):
            return wordnet.NOUN
        elif tag.startswith('R'):
            return wordnet.ADV
        else:
            return wordnet.NOUN

    def lemmatize_reviews(self, reviews):
        wnl = WordNetLemmatizer()
        
        def lemmatize_token(token):
            if isinstance(token, tuple) and len(token) == 2:
                word, tag = token
                return (wnl.lemmatize(word, self.get_wordnet_pos(tag)), tag)
                
        return reviews.apply(lambda tokens: [lemmatize_token(token) for token in tokens])

# %%
df_product_reviews["review_preprocessed"] = Preprocess().main(df_product_reviews["review"])

df_product_reviews[["product", "review", "review_preprocessed"]]
# Out:
#                      product  \
# 0                 Nokia 6610
# 1                 Nokia 6610
# 2                 Nokia 6610
# 3                 Nokia 6610
# 4                 Nokia 6610
# ...                      ...
# 10915  Canon PowerShot SD500
# 10916  Canon PowerShot SD500
# 10917  Canon PowerShot SD500
# 10918  Canon PowerShot SD500
# 10919  Canon PowerShot SD500
#
#                                                   review  \
# 0                  excellent phone , excellent service .
# 1      i am a business user who heavily depend on mob...
# 2      there is much which has been said in other rev...
# 3      just double check with customer service to ens...
# 4      after several years of torture in the hands of...
# ...                                                  ...
# 10915  There were many times when I clicked the autom...
# 10916  It seems you have to double click some of the ...
# 10917  Huh? I missed out on lots of photos and lots a...
# 10918  The controls are hard to manipulate, especiall...
# 10919  The LCD screen is too small since there are so...
#
#                                      review_preprocessed
# 0      [(excellent, JJ), (phone, NN), (, NNP), (excel...
# 1      [(business, NN), (user, VBD), (heavily, RB), (...
# 2      [(much, RB), (say, VBD), (reviews, JJ), (featu...
# 3      [(double, RB), (check, VB), (customer, NN), (s...
# 4      [(several, JJ), (year, NNS), (torture, JJ), (h...
# ...                                                  ...
# 10915  [(many, JJ), (time, NNS), (click, VBD), (autom...
# 10916  [(seem, VBZ), (double, JJ), (click, JJ), (time...
# 10917  [(huh, NN), (, NNS), (miss, VBD), (lot, NNS), ...
# 10918  [(control, NNS), (hard, JJ), (manipulate, NN),...
# 10919  [(lcd, NN), (screen, NN), (small, JJ), (since,...
#
# [10920 rows x 3 columns]

# %% [markdown]
# ## Frequent Feature Identification

# %%
pd.set_option('display.max_row', 100)
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from collections import defaultdict
    
def extract_potential_features(pos_tagged_reviews):
    return [[word for word, pos in review if pos.startswith('NN') or pos.startswith('NG')] for review in pos_tagged_reviews]

frequent_features = {}

for product_name, group in df_product_reviews.groupby('product'):
    reviews_df = group['review_preprocessed'].tolist()
    reviews = extract_potential_features(reviews_df)
    te = TransactionEncoder()
    te_ary = te.fit(reviews).transform(reviews)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
    print(frequent_itemsets, 'frequent_itemsets')
    
    # From here onwards it looks like we perform pruning?
    # double checked and this looks to be compactness pruning. We just want to find two or more words that appear close
    # to each 
    frequent_items = frequent_itemsets['itemsets'].tolist()
    frequent_compact_items = defaultdict(lambda: 0)
    reviews = group['review'].tolist()
    reviews = [review.split() for review in reviews]
    for ind, review in enumerate(reviews):
        for items in frequent_items:
            index_of_items = []
            for item in items:
                if item in review:
                    index_of_items.append(review.index(item))
            if len(index_of_items) == len(items) and max(index_of_items) - min(index_of_items) < 3:
                frequent_compact_items[items] += 1
    
    result_items = [item for item, val in frequent_compact_items.items() if val > 2]
    
    multi_word_item = {}
    for item, val in frequent_compact_items.items():
        if len(item) > 1:
           multi_word_item[item] = val
    p_support = defaultdict(lambda:[])
    for item, val in multi_word_item.items():
        for itm in item:
            p_support[itm].append(val)
    
    min_p_support = 3
    for item, counts in p_support.items():
        if min(counts) <= min_p_support and frozenset([item]) in result_items:
            result_items.remove(frozenset([item]))

    frequent_itemsets = frequent_itemsets[frequent_itemsets['itemsets'].isin(result_items)]
    frequent_items =  frequent_itemsets['itemsets'].tolist()
    tags = []
    for ind, review in enumerate(reviews):
        tag = []
        
        for items in frequent_items:
            count = 0
            for item in items:
                if item in review:
                    count += 1
            if count == len(items):
                tag.append(items)
        tags.append(tag)

    group['tags'] = tags
    frequent_features[product_name] = frequent_itemsets

for product, df in frequent_features.items():
    print(f"Frequent itemsets for {product}:")
    sorted_df = df.sort_values(by='support')
    print(sorted_df)
    print("\n")
# Out:
#      support                itemsets
# 0   0.021454                (ad2600)
# 1   0.017878                (amazon)
# 2   0.060787                  (apex)
# 3   0.015495                 (brand)
# 4   0.025030                (button)
# 5   0.010727                   (buy)
# 6   0.013111                    (cd)
# 7   0.022646             (christmas)
# 8   0.010727               (control)
# 9   0.027414              (customer)
# 10  0.021454                   (day)
# 11  0.026222                  (disc)
# 12  0.010727                  (disk)
# 13  0.015495               (display)
# 14  0.175209                   (dvd)
# 15  0.019070            (everything)
# 16  0.035757               (feature)
# 17  0.013111                (format)
# 18  0.016687                   (get)
# 19  0.014303                  (gift)
# 20  0.011919                  (hour)
# 21  0.010727                   (lot)
# 22  0.020262               (machine)
# 23  0.014303                 (model)
# 24  0.026222                 (money)
# 25  0.033373                 (month)
# 26  0.023838                 (movie)
# 27  0.013111                (number)
# 28  0.014303                (output)
# 29  0.036949               (picture)
# 30  0.066746                  (play)
# 31  0.177592                (player)
# 32  0.035757                 (price)
# 33  0.065554               (problem)
# 34  0.027414               (product)
# 35  0.013111              (purchase)
# 36  0.025030               (quality)
# 37  0.014303                (remote)
# 38  0.011919                (return)
# 39  0.020262                (review)
# 40  0.026222               (service)
# 41  0.011919             (something)
# 42  0.011919               (support)
# 43  0.023838                 (thing)
# 44  0.027414                  (time)
# 45  0.010727                   (try)
# 46  0.011919                    (tv)
# 47  0.035757                  (unit)
# 48  0.014303                   (use)
# 49  0.023838                 (video)
# 50  0.011919                   (way)
# 51  0.021454                  (week)
# 52  0.029797                  (work)
# 53  0.013111                  (year)
# 54  0.015495             (apex, dvd)
# 55  0.016687          (player, apex)
# 56  0.022646     (service, customer)
# 57  0.010727          (feature, dvd)
# 58  0.021454             (dvd, play)
# 59  0.108462           (player, dvd)
# 60  0.017878          (problem, dvd)
# 61  0.010727      (everything, play)
# 62  0.017878          (player, play)
# 63  0.013111         (price, player)
# 64  0.015495       (problem, player)
# 65  0.014303     (player, apex, dvd)
# 66  0.013111     (player, dvd, play)
# 67  0.011919  (problem, player, dvd) frequent_itemsets
#      support             itemsets
# 0   0.012461               (auto)
# 1   0.035826            (battery)
# 2   0.012461             (button)
# 3   0.010903                (buy)
# 4   0.322430             (camera)
# 5   0.080997              (canon)
# 6   0.021807               (card)
# 7   0.012461             (choice)
# 8   0.014019              (color)
# 9   0.021807            (control)
# 10  0.010903                (day)
# 11  0.010903         (everything)
# 12  0.035826            (feature)
# 13  0.017134               (feel)
# 14  0.026480               (film)
# 15  0.040498              (flash)
# 16  0.015576               (flaw)
# 17  0.010903              (focus)
# 18  0.021807                 (g2)
# 19  0.079439                 (g3)
# 20  0.012461                (get)
# 21  0.010903               (hand)
# 22  0.045171              (image)
# 23  0.012461                (lcd)
# 24  0.024922               (lens)
# 25  0.017134               (life)
# 26  0.017134                (lot)
# 27  0.014019          (megapixel)
# 28  0.026480               (mode)
# 29  0.015576             (moment)
# 30  0.012461              (month)
# 31  0.018692                 (nt)
# 32  0.017134             (option)
# 33  0.046729              (photo)
# 34  0.012461        (photography)
# 35  0.012461                (pic)
# 36  0.088785            (picture)
# 37  0.024922              (point)
# 38  0.015576              (price)
# 39  0.017134            (problem)
# 40  0.060748            (quality)
# 41  0.017134              (range)
# 42  0.010903           (research)
# 43  0.014019         (resolution)
# 44  0.014019             (result)
# 45  0.024922             (review)
# 46  0.010903             (screen)
# 47  0.017134            (setting)
# 48  0.023364              (shoot)
# 49  0.017134               (shot)
# 50  0.023364            (shutter)
# 51  0.010903                (slr)
# 52  0.024922           (software)
# 53  0.010903          (something)
# 54  0.010903              (store)
# 55  0.023364              (thing)
# 56  0.057632               (time)
# 57  0.063863                (use)
# 58  0.010903               (view)
# 59  0.024922         (viewfinder)
# 60  0.014019                (way)
# 61  0.012461               (work)
# 62  0.012461               (year)
# 63  0.026480               (zoom)
# 64  0.012461    (camera, battery)
# 65  0.014019      (life, battery)
# 66  0.029595      (camera, canon)
# 67  0.017134    (camera, feature)
# 68  0.012461       (film, camera)
# 69  0.012461      (flash, camera)
# 70  0.028037         (camera, g3)
# 71  0.014019      (image, camera)
# 72  0.012461        (camera, lot)
# 73  0.010903      (camera, photo)
# 74  0.015576    (camera, picture)
# 75  0.017134    (camera, quality)
# 76  0.014019     (review, camera)
# 77  0.010903   (software, camera)
# 78  0.014019      (thing, camera)
# 79  0.018692       (time, camera)
# 80  0.026480        (camera, use)
# 81  0.028037          (g3, canon)
# 82  0.010903          (image, g3)
# 83  0.012461        (g3, quality)
# 84  0.014019     (image, quality)
# 85  0.020249   (picture, quality)
# 86  0.017134       (point, shoot)
# 87  0.014019  (camera, g3, canon) frequent_itemsets
#       support                        itemsets
# 0    0.017391                          (auto)
# 1    0.013043                       (balance)
# 2    0.026087                       (battery)
# 3    0.017391                           (bit)
# 4    0.021739                        (button)
# ..        ...                             ...
# 113  0.017391      (picture, camera, quality)
# 114  0.013043        (thing, camera, quality)
# 115  0.017391        (video, camera, quality)
# 116  0.013043          (video, clip, quality)
# 117  0.013043  (video, camera, clip, quality)
#
# [118 rows x 2 columns] frequent_itemsets
#      support                    itemsets
# 0   0.011461                   (balance)
# 1   0.065903                   (battery)
# 2   0.014327                    (button)
# 3   0.320917                    (camera)
# 4   0.037249                     (canon)
# 5   0.051576                      (card)
# 6   0.017192                      (case)
# 7   0.011461                    (choice)
# 8   0.014327                     (color)
# 9   0.014327                  (computer)
# 10  0.011461                   (control)
# 11  0.022923                      (elph)
# 12  0.017192                  (exposure)
# 13  0.011461                      (film)
# 14  0.011461                     (flash)
# 15  0.011461                      (flaw)
# 16  0.014327                     (focus)
# 17  0.014327                  (function)
# 18  0.025788                     (image)
# 19  0.020057                       (lcd)
# 20  0.011461                     (macro)
# 21  0.034384                    (memory)
# 22  0.031519                      (mode)
# 23  0.011461                     (money)
# 24  0.014327                     (month)
# 25  0.014327                      (need)
# 26  0.017192                        (nt)
# 27  0.011461                  (panorama)
# 28  0.017192                     (photo)
# 29  0.017192               (photography)
# 30  0.106017                   (picture)
# 31  0.020057                    (pocket)
# 32  0.020057                     (point)
# 33  0.022923                     (price)
# 34  0.014327                     (print)
# 35  0.028653                   (problem)
# 36  0.025788                   (quality)
# 37  0.017192                (resolution)
# 38  0.011461                    (result)
# 39  0.014327                    (review)
# 40  0.031519                      (s100)
# 41  0.017192                     (shoot)
# 42  0.025788                      (shot)
# 43  0.042980                      (size)
# 44  0.014327                       (slr)
# 45  0.031519                  (software)
# 46  0.017192                 (something)
# 47  0.011461                      (star)
# 48  0.020057                     (thing)
# 49  0.025788                      (time)
# 50  0.057307                       (use)
# 51  0.011461                       (way)
# 52  0.011461                      (wife)
# 53  0.011461                      (work)
# 54  0.022923                      (year)
# 55  0.031519                      (zoom)
# 56  0.025788           (camera, battery)
# 57  0.011461             (battery, card)
# 58  0.011461             (case, battery)
# 59  0.020057             (camera, canon)
# 60  0.011461              (camera, card)
# 61  0.011461              (case, camera)
# 62  0.011461            (camera, choice)
# 63  0.014327              (elph, camera)
# 64  0.017192             (image, camera)
# 65  0.042980           (picture, camera)
# 66  0.014327             (camera, point)
# 67  0.011461             (price, camera)
# 68  0.011461           (problem, camera)
# 69  0.014327           (camera, quality)
# 70  0.014327             (camera, shoot)
# 71  0.020057              (size, camera)
# 72  0.011461               (camera, slr)
# 73  0.020057               (camera, use)
# 74  0.017192              (camera, year)
# 75  0.014327              (zoom, camera)
# 76  0.011461               (elph, canon)
# 77  0.017192               (s100, canon)
# 78  0.025788              (memory, card)
# 79  0.011461               (thing, card)
# 80  0.011461             (memory, thing)
# 81  0.020057          (picture, quality)
# 82  0.011461              (point, shoot)
# 83  0.011461                (point, use)
# 84  0.011461           (time, something)
# 85  0.011461     (case, camera, battery)
# 86  0.011461  (picture, camera, quality)
# 87  0.011461      (camera, point, shoot)
# 88  0.011461       (memory, thing, card) frequent_itemsets
#      support            itemsets
# 0   0.054614              (acer)
# 1   0.020716             (apple)
# 2   0.016949             (brand)
# 3   0.011299             (cable)
# 4   0.016949              (case)
# 5   0.013183            (change)
# 6   0.033898             (color)
# 7   0.060264          (computer)
# 8   0.015066          (customer)
# 9   0.016949               (day)
# 10  0.015066              (deal)
# 11  0.015066              (dell)
# 12  0.011299              (desk)
# 13  0.032015           (display)
# 14  0.011299        (everything)
# 15  0.015066        (experience)
# 16  0.013183              (home)
# 17  0.018832             (image)
# 18  0.018832             (issue)
# 19  0.016949              (item)
# 20  0.015066          (keyboard)
# 21  0.015066               (lcd)
# 22  0.015066              (life)
# 23  0.011299               (lot)
# 24  0.032015               (lrb)
# 25  0.013183           (machine)
# 26  0.013183             (money)
# 27  0.186441           (monitor)
# 28  0.018832             (month)
# 29  0.011299             (movie)
# 30  0.013183              (need)
# 31  0.020716           (netbook)
# 32  0.015066                (nt)
# 33  0.011299            (office)
# 34  0.011299            (others)
# 35  0.013183                (pc)
# 36  0.013183            (people)
# 37  0.020716           (picture)
# 38  0.011299             (power)
# 39  0.060264             (price)
# 40  0.043315           (problem)
# 41  0.043315           (product)
# 42  0.022599          (purchase)
# 43  0.024482           (quality)
# 44  0.016949            (repair)
# 45  0.013183       (replacement)
# 46  0.011299        (resolution)
# 47  0.018832            (review)
# 48  0.048964               (rrb)
# 49  0.037665            (screen)
# 50  0.016949           (service)
# 51  0.015066              (size)
# 52  0.011299         (something)
# 53  0.018832           (support)
# 54  0.016949             (thing)
# 55  0.052731              (time)
# 56  0.011299              (unit)
# 57  0.018832               (use)
# 58  0.011299             (video)
# 59  0.011299          (warranty)
# 60  0.011299              (week)
# 61  0.011299            (window)
# 62  0.033898              (work)
# 63  0.011299              (year)
# 64  0.015066     (acer, monitor)
# 65  0.011299      (lcd, monitor)
# 66  0.024482          (lrb, rrb)
# 67  0.024482    (price, monitor)
# 68  0.011299  (problem, monitor)
# 69  0.013183      (monitor, rrb)
# 70  0.016949   (monitor, screen) frequent_itemsets
#      support            itemsets
# 0   0.012700             (album)
# 1   0.013805             (apple)
# 2   0.042518           (battery)
# 3   0.023744            (button)
# 4   0.013805               (buy)
# 5   0.023744              (case)
# 6   0.039757                (cd)
# 7   0.014357        (collection)
# 8   0.030922          (computer)
# 9   0.011044               (con)
# 10  0.011044           (control)
# 11  0.014909               (day)
# 12  0.021535            (device)
# 13  0.020431             (drive)
# 14  0.017118           (feature)
# 15  0.039757              (file)
# 16  0.011044            (folder)
# 17  0.011596                (gb)
# 18  0.011044               (get)
# 19  0.019326         (headphone)
# 20  0.011044              (hour)
# 21  0.011596         (interface)
# 22  0.061844              (ipod)
# 23  0.011596              (jack)
# 24  0.014909           (jukebox)
# 25  0.011596              (life)
# 26  0.011044               (lot)
# 27  0.015461       (mediasource)
# 28  0.011044            (memory)
# 29  0.013805             (month)
# 30  0.042518               (mp3)
# 31  0.051353             (music)
# 32  0.010491              (name)
# 33  0.031474                (nt)
# 34  0.024296            (people)
# 35  0.010491              (play)
# 36  0.150193            (player)
# 37  0.015461          (playlist)
# 38  0.034235             (price)
# 39  0.041414           (problem)
# 40  0.039205           (product)
# 41  0.033131           (quality)
# 42  0.015461            (review)
# 43  0.015461            (scroll)
# 44  0.013252              (size)
# 45  0.084484          (software)
# 46  0.013252         (something)
# 47  0.056322              (song)
# 48  0.020431             (sound)
# 49  0.015461           (storage)
# 50  0.011596           (support)
# 51  0.016565               (tag)
# 52  0.043070             (thing)
# 53  0.028161              (time)
# 54  0.018222             (track)
# 55  0.021535          (transfer)
# 56  0.020983              (unit)
# 57  0.043070               (use)
# 58  0.012700          (warranty)
# 59  0.015461               (way)
# 60  0.012700              (week)
# 61  0.012700            (window)
# 62  0.013805              (work)
# 63  0.028713              (xtra)
# 64  0.011596              (year)
# 65  0.037548               (zen)
# 66  0.034235       (player, mp3)
# 67  0.012700     (music, player)
# 68  0.013252  (software, player)
# 69  0.011044     (software, use)
# 70  0.015461         (xtra, zen) frequent_itemsets
#      support                 itemsets
# 0   0.047170                   (baby)
# 1   0.172170                    (bag)
# 2   0.136792                  (champ)
# 3   0.028302                 (change)
# 4   0.016509                  (child)
# 5   0.275943                 (diaper)
# 6   0.025943                  (dirty)
# 7   0.011792                   (dump)
# 8   0.016509                   (fact)
# 9   0.028302                   (flip)
# 10  0.033019                (garbage)
# 11  0.066038                  (genie)
# 12  0.014151                    (get)
# 13  0.014151                   (hand)
# 14  0.021226                 (handle)
# 15  0.023585                (kitchen)
# 16  0.011792                  (money)
# 17  0.040094                  (month)
# 18  0.030660                     (nt)
# 19  0.061321                   (odor)
# 20  0.082547                   (pail)
# 21  0.035377                (problem)
# 22  0.037736                (product)
# 23  0.016509               (purchase)
# 24  0.044811                 (refill)
# 25  0.018868                 (review)
# 26  0.021226                   (room)
# 27  0.047170                  (smell)
# 28  0.018868                    (son)
# 29  0.014151                  (thing)
# 30  0.035377                   (time)
# 31  0.023585                (toddler)
# 32  0.042453                  (trash)
# 33  0.075472                    (use)
# 34  0.018868                    (way)
# 35  0.018868                   (week)
# 36  0.033019                   (work)
# 37  0.018868                   (year)
# 38  0.030660           (baby, diaper)
# 39  0.037736             (bag, champ)
# 40  0.016509            (bag, change)
# 41  0.058962            (bag, diaper)
# 42  0.028302           (garbage, bag)
# 43  0.016509             (bag, genie)
# 44  0.021226           (bag, kitchen)
# 45  0.014151              (bag, pail)
# 46  0.011792          (purchase, bag)
# 47  0.018868            (bag, refill)
# 48  0.011792              (time, bag)
# 49  0.035377             (trash, bag)
# 50  0.035377               (bag, use)
# 51  0.075472          (diaper, champ)
# 52  0.014151           (genie, champ)
# 53  0.014151            (odor, champ)
# 54  0.011792           (smell, champ)
# 55  0.011792            (time, champ)
# 56  0.016509             (use, champ)
# 57  0.011792         (change, diaper)
# 58  0.023585          (dirty, diaper)
# 59  0.047170          (diaper, genie)
# 60  0.011792            (get, diaper)
# 61  0.021226           (odor, diaper)
# 62  0.042453           (diaper, pail)
# 63  0.011792        (problem, diaper)
# 64  0.016509         (diaper, refill)
# 65  0.016509          (smell, diaper)
# 66  0.011792           (time, diaper)
# 67  0.021226          (trash, diaper)
# 68  0.023585            (diaper, use)
# 69  0.018868           (handle, flip)
# 70  0.011792           (garbage, use)
# 71  0.016509          (genie, refill)
# 72  0.011792         (trash, kitchen)
# 73  0.011792           (use, kitchen)
# 74  0.011792          (problem, odor)
# 75  0.016509              (odor, use)
# 76  0.014151             (trash, use)
# 77  0.016509     (bag, diaper, champ)
# 78  0.014151     (bag, diaper, genie)
# 79  0.011792    (bag, diaper, refill)
# 80  0.016509     (trash, bag, diaper)
# 81  0.011792    (trash, bag, kitchen)
# 82  0.011792      (bag, use, kitchen)
# 83  0.014151        (trash, bag, use)
# 84  0.011792    (odor, diaper, champ)
# 85  0.011792     (diaper, use, champ)
# 86  0.011792  (genie, diaper, refill) frequent_itemsets
#      support              itemsets
# 0   0.011662              (action)
# 1   0.046647          (adjustment)
# 2   0.014577              (amazon)
# 3   0.011662                (base)
# 4   0.122449                 (bit)
# 5   0.014577               (bosch)
# 6   0.014577              (change)
# 7   0.011662               (chuck)
# 8   0.026239              (collet)
# 9   0.049563             (control)
# 10  0.034985                 (cut)
# 11  0.032070               (depth)
# 12  0.017493                (edge)
# 13  0.014577            (freehand)
# 14  0.014577                 (get)
# 15  0.020408               (guide)
# 16  0.052478                (hand)
# 17  0.011662              (handle)
# 18  0.049563             (hitachi)
# 19  0.011662                  (hp)
# 20  0.011662                (inch)
# 21  0.029155                (knob)
# 22  0.026239                (lock)
# 23  0.026239                (m12v)
# 24  0.037901             (machine)
# 25  0.011662           (mechanism)
# 26  0.026239               (money)
# 27  0.011662                (need)
# 28  0.023324                  (nt)
# 29  0.017493           (operation)
# 30  0.023324               (panel)
# 31  0.034985              (plunge)
# 32  0.046647               (power)
# 33  0.043732               (price)
# 34  0.029155             (problem)
# 35  0.256560              (router)
# 36  0.014577                (shop)
# 37  0.064140               (speed)
# 38  0.014577              (spring)
# 39  0.017493               (start)
# 40  0.072886               (table)
# 41  0.017493               (thing)
# 42  0.017493                (time)
# 43  0.043732                (tool)
# 44  0.104956                 (use)
# 45  0.017493                (wood)
# 46  0.029155                (work)
# 47  0.014577              (wrench)
# 48  0.034985                (year)
# 49  0.011662     (adjustment, bit)
# 50  0.011662   (depth, adjustment)
# 51  0.023324    (knob, adjustment)
# 52  0.011662  (adjustment, router)
# 53  0.011662         (collet, bit)
# 54  0.014577            (cut, bit)
# 55  0.011662           (hand, bit)
# 56  0.011662           (inch, bit)
# 57  0.011662           (lock, bit)
# 58  0.014577          (panel, bit)
# 59  0.011662          (power, bit)
# 60  0.029155         (router, bit)
# 61  0.014577          (speed, bit)
# 62  0.011662          (bit, table)
# 63  0.014577            (use, bit)
# 64  0.037901      (speed, control)
# 65  0.011662       (freehand, use)
# 66  0.014577        (router, hand)
# 67  0.011662         (hand, table)
# 68  0.011662           (hand, use)
# 69  0.011662       (hitachi, m12v)
# 70  0.011662        (knob, router)
# 71  0.011662        (lock, router)
# 72  0.011662        (router, m12v)
# 73  0.020408       (money, router)
# 74  0.011662             (nt, use)
# 75  0.020408      (plunge, router)
# 76  0.014577        (power, speed)
# 77  0.014577       (price, router)
# 78  0.011662        (shop, router)
# 79  0.017493       (speed, router)
# 80  0.064140       (router, table)
# 81  0.037901         (router, use)
# 82  0.023324        (router, year)
# 83  0.011662          (speed, use)
# 84  0.020408          (use, table)
# 85  0.011662           (tool, use)
# 86  0.017493  (use, router, table) frequent_itemsets
#      support             itemsets
# 0   0.022690             (access)
# 1   0.016207            (address)
# 2   0.016207                (box)
# 3   0.024311              (cable)
# 4   0.021070               (card)
# 5   0.047002                 (cd)
# 6   0.050243           (computer)
# 7   0.019449      (configuration)
# 8   0.012966            (connect)
# 9   0.047002         (connection)
# 10  0.011345             (couple)
# 11  0.012966                (day)
# 12  0.012966             (device)
# 13  0.012966      (documentation)
# 14  0.019449         (encryption)
# 15  0.011345           (ethernet)
# 16  0.012966         (everything)
# 17  0.012966         (experience)
# 18  0.014587            (feature)
# 19  0.014587               (file)
# 20  0.027553           (firmware)
# 21  0.011345                (get)
# 22  0.014587           (hardware)
# 23  0.016207               (help)
# 24  0.012966               (home)
# 25  0.012966               (hour)
# 26  0.016207              (house)
# 27  0.017828       (installation)
# 28  0.022690        (instruction)
# 29  0.011345           (internet)
# 30  0.019449              (issue)
# 31  0.058347            (linksys)
# 32  0.011345                (lot)
# 33  0.021070                (mac)
# 34  0.016207             (minute)
# 35  0.032415              (modem)
# 36  0.012966               (need)
# 37  0.058347            (network)
# 38  0.011345                 (nt)
# 39  0.024311                 (pc)
# 40  0.016207             (people)
# 41  0.012966              (point)
# 42  0.012966              (price)
# 43  0.051864            (problem)
# 44  0.043760            (product)
# 45  0.016207            (program)
# 46  0.011345              (range)
# 47  0.016207             (review)
# 48  0.200972             (router)
# 49  0.038898           (security)
# 50  0.017828            (service)
# 51  0.055105              (setup)
# 52  0.017828               (site)
# 53  0.014587           (software)
# 54  0.014587            (someone)
# 55  0.030794              (speed)
# 56  0.011345               (star)
# 57  0.011345               (step)
# 58  0.030794            (support)
# 59  0.021070             (system)
# 60  0.027553              (thing)
# 61  0.038898               (time)
# 62  0.030794                (use)
# 63  0.011345               (user)
# 64  0.017828            (version)
# 65  0.016207                (way)
# 66  0.072934           (wireless)
# 67  0.040519               (work)
# 68  0.022690             (wrt54g)
# 69  0.014587               (year)
# 70  0.014587       (modem, cable)
# 71  0.019449   (computer, router)
# 72  0.029173    (linksys, router)
# 73  0.016207  (linksys, wireless)
# 74  0.012966    (network, router)
# 75  0.016207  (network, wireless)
# 76  0.011345    (problem, router)
# 77  0.016207   (router, security)
# 78  0.016207      (setup, router)
# 79  0.012966        (router, use)
# 80  0.035656   (wireless, router)
# 81  0.011345       (work, router) frequent_itemsets
#      support           itemsets
# 0   0.010377          (ability)
# 1   0.021698            (apple)
# 2   0.055660          (battery)
# 3   0.016981           (button)
# 4   0.010377            (cable)
# 5   0.011321             (case)
# 6   0.019811               (cd)
# 7   0.011321          (company)
# 8   0.022642         (computer)
# 9   0.014151              (day)
# 10  0.015094           (design)
# 11  0.019811           (device)
# 12  0.010377         (download)
# 13  0.014151            (drive)
# 14  0.035849          (feature)
# 15  0.026415             (file)
# 16  0.022642         (firmware)
# 17  0.018868               (fm)
# 18  0.013208              (get)
# 19  0.011321             (hand)
# 20  0.032075        (headphone)
# 21  0.018868             (hour)
# 22  0.016038        (interface)
# 23  0.057547             (ipod)
# 24  0.012264            (issue)
# 25  0.016038           (itunes)
# 26  0.019811             (life)
# 27  0.010377             (list)
# 28  0.011321             (look)
# 29  0.015094              (lot)
# 30  0.015094           (medium)
# 31  0.093396            (micro)
# 32  0.020755             (mini)
# 33  0.014151            (month)
# 34  0.046226              (mp3)
# 35  0.040566            (music)
# 36  0.032075               (nt)
# 37  0.010377              (pad)
# 38  0.011321               (pc)
# 39  0.018868           (people)
# 40  0.012264             (play)
# 41  0.165094           (player)
# 42  0.017925            (price)
# 43  0.033019          (problem)
# 44  0.033019          (product)
# 45  0.018868         (purchase)
# 46  0.031132          (quality)
# 47  0.020755            (radio)
# 48  0.027358           (review)
# 49  0.012264          (service)
# 50  0.010377             (size)
# 51  0.037736         (software)
# 52  0.016981        (something)
# 53  0.043396             (song)
# 54  0.028302            (sound)
# 55  0.012264          (storage)
# 56  0.016038            (store)
# 57  0.012264          (support)
# 58  0.032075            (thing)
# 59  0.027358             (time)
# 60  0.043396              (use)
# 61  0.015094             (week)
# 62  0.011321           (window)
# 63  0.010377             (work)
# 64  0.011321             (year)
# 65  0.086792              (zen)
# 66  0.014151    (life, battery)
# 67  0.010377  (player, battery)
# 68  0.012264       (mini, ipod)
# 69  0.010377   (player, medium)
# 70  0.014151    (micro, player)
# 71  0.053774       (micro, zen)
# 72  0.033962      (player, mp3)
# 73  0.013208  (problem, player)
# 74  0.011321     (song, player)
# 75  0.011321      (player, use)
# 76  0.011321      (zen, player) frequent_itemsets
#       support                    itemsets
# 0    0.013158                   (adapter)
# 1    0.013158                      (auto)
# 2    0.068421                   (battery)
# 3    0.013158                  (beginner)
# 4    0.347368                    (camera)
# ..        ...                         ...
# 96   0.013158             (size, picture)
# 97   0.010526              (point, shoot)
# 98   0.013158              (price, range)
# 99   0.015789             (size, quality)
# 100  0.010526  (picture, camera, quality)
#
# [101 rows x 2 columns] frequent_itemsets
#      support           itemsets
# 0   0.014925      (application)
# 1   0.028192          (battery)
# 2   0.013267        (bluetooth)
# 3   0.021559             (call)
# 4   0.044776           (camera)
# 5   0.034826             (card)
# 6   0.013267             (cell)
# 7   0.013267            (color)
# 8   0.013267          (company)
# 9   0.024876         (computer)
# 10  0.016584          (contact)
# 11  0.023217              (day)
# 12  0.018242           (device)
# 13  0.013267       (everything)
# 14  0.053068          (feature)
# 15  0.023217             (game)
# 16  0.011609             (hand)
# 17  0.011609             (hour)
# 18  0.014925        (interface)
# 19  0.011609              (key)
# 20  0.023217             (life)
# 21  0.018242              (lot)
# 22  0.023217           (memory)
# 23  0.011609             (menu)
# 24  0.013267          (message)
# 25  0.016584            (month)
# 26  0.011609             (need)
# 27  0.014925            (nokia)
# 28  0.019900               (nt)
# 29  0.021559           (number)
# 30  0.013267            (offer)
# 31  0.011609              (pda)
# 32  0.023217           (people)
# 33  0.356551            (phone)
# 34  0.018242          (picture)
# 35  0.021559          (problem)
# 36  0.031509          (quality)
# 37  0.013267           (rebate)
# 38  0.014925        (reception)
# 39  0.013267           (repair)
# 40  0.028192           (screen)
# 41  0.014925           (second)
# 42  0.018242          (service)
# 43  0.016584             (size)
# 44  0.014925             (sony)
# 45  0.016584          (speaker)
# 46  0.013267          (support)
# 47  0.013267           (system)
# 48  0.024876            (thing)
# 49  0.034826             (time)
# 50  0.021559          (tmobile)
# 51  0.013267         (transfer)
# 52  0.054726              (use)
# 53  0.023217            (video)
# 54  0.013267              (way)
# 55  0.024876             (work)
# 56  0.013267             (year)
# 57  0.016584    (life, battery)
# 58  0.023217    (camera, phone)
# 59  0.014925     (memory, card)
# 60  0.019900      (card, phone)
# 61  0.011609      (phone, cell)
# 62  0.014925  (computer, phone)
# 63  0.013267    (device, phone)
# 64  0.026534   (feature, phone)
# 65  0.011609    (phone, people)
# 66  0.013267   (phone, quality)
# 67  0.013267    (phone, screen)
# 68  0.013267   (phone, speaker)
# 69  0.013267      (time, phone)
# 70  0.026534       (phone, use)
# 71  0.014925      (work, phone) frequent_itemsets
#      support               itemsets
# 0   0.011925               (access)
# 1   0.010221                 (area)
# 2   0.028961              (battery)
# 3   0.010221               (button)
# 4   0.018739               (camera)
# 5   0.011925                 (cell)
# 6   0.020443                (color)
# 7   0.010221                  (con)
# 8   0.010221             (customer)
# 9   0.017036                  (day)
# 10  0.011925                (email)
# 11  0.073254              (feature)
# 12  0.010221                   (fm)
# 13  0.013629             (function)
# 14  0.020443                 (game)
# 15  0.010221              (headset)
# 16  0.015332                 (hour)
# 17  0.010221             (internet)
# 18  0.010221                  (key)
# 19  0.023850                 (life)
# 20  0.017036                  (lot)
# 21  0.020443                 (menu)
# 22  0.010221                (music)
# 23  0.015332               (number)
# 24  0.027257               (option)
# 25  0.018739               (people)
# 26  0.010221               (person)
# 27  0.405451                (phone)
# 28  0.018739                 (plan)
# 29  0.010221               (pocket)
# 30  0.022147              (problem)
# 31  0.035775              (quality)
# 32  0.010221             (question)
# 33  0.035775                (radio)
# 34  0.022147            (reception)
# 35  0.017036            (ringtones)
# 36  0.015332              (samsung)
# 37  0.025554               (screen)
# 38  0.051107              (service)
# 39  0.022147                 (size)
# 40  0.010221                 (sony)
# 41  0.015332                (sound)
# 42  0.027257         (speakerphone)
# 43  0.022147                (thing)
# 44  0.023850                 (time)
# 45  0.034072              (tmobile)
# 46  0.015332                 (tone)
# 47  0.018739               (tzones)
# 48  0.028961                  (use)
# 49  0.022147                (voice)
# 50  0.015332               (volume)
# 51  0.013629                  (way)
# 52  0.010221                 (week)
# 53  0.022147                 (work)
# 54  0.015332                 (year)
# 55  0.020443        (life, battery)
# 56  0.011925       (battery, phone)
# 57  0.010221        (camera, phone)
# 58  0.011925          (phone, cell)
# 59  0.011925        (color, screen)
# 60  0.032368       (feature, phone)
# 61  0.011925          (life, phone)
# 62  0.010221        (option, phone)
# 63  0.010221       (problem, phone)
# 64  0.011925       (phone, quality)
# 65  0.010221         (radio, phone)
# 66  0.011925       (samsung, phone)
# 67  0.015332       (service, phone)
# 68  0.010221          (phone, sony)
# 69  0.011925  (speakerphone, phone)
# 70  0.015332         (thing, phone)
# 71  0.010221       (phone, tmobile)
# 72  0.013629           (use, phone)
# 73  0.013629         (voice, phone)
# 74  0.010221          (work, phone)
# 75  0.010221          (phone, year)
# 76  0.011925       (sound, quality)
# 77  0.010221     (service, tmobile) frequent_itemsets
#      support                 itemsets
# 0   0.025028                 (access)
# 1   0.010239                (adapter)
# 2   0.020478                (address)
# 3   0.019340                    (box)
# 4   0.012514                (buffalo)
# 5   0.010239                    (buy)
# 6   0.011377                  (cable)
# 7   0.013652                 (change)
# 8   0.036405               (computer)
# 9   0.038680             (connection)
# 10  0.017065               (customer)
# 11  0.013652                    (day)
# 12  0.011377                  (ddwrt)
# 13  0.011377                (desktop)
# 14  0.038680                 (device)
# 15  0.010239                 (dir655)
# 16  0.021615                  (dlink)
# 17  0.012514                  (drive)
# 18  0.010239               (ethernet)
# 19  0.013652             (everything)
# 20  0.015927                (feature)
# 21  0.036405               (firmware)
# 22  0.017065                   (home)
# 23  0.019340                   (hour)
# 24  0.020478                  (house)
# 25  0.010239           (installation)
# 26  0.025028               (internet)
# 27  0.017065                     (ip)
# 28  0.011377                  (issue)
# 29  0.013652                 (laptop)
# 30  0.011377                   (line)
# 31  0.020478                (linksys)
# 32  0.047782                    (lrb)
# 33  0.011377                   (mbps)
# 34  0.021615                 (minute)
# 35  0.015927                  (model)
# 36  0.022753                  (modem)
# 37  0.021615                  (month)
# 38  0.058020                (network)
# 39  0.019340                (nfinity)
# 40  0.018203                     (nt)
# 41  0.018203                 (number)
# 42  0.018203               (password)
# 43  0.010239                     (pc)
# 44  0.010239                 (people)
# 45  0.011377                  (phone)
# 46  0.020478                  (point)
# 47  0.022753                   (port)
# 48  0.017065                  (power)
# 49  0.011377                  (price)
# 50  0.017065                (printer)
# 51  0.053470                (problem)
# 52  0.046644                (product)
# 53  0.020478                  (range)
# 54  0.013652            (replacement)
# 55  0.010239                 (review)
# 56  0.201365                 (router)
# 57  0.087600                    (rrb)
# 58  0.012514               (security)
# 59  0.018203                (service)
# 60  0.015927                (setting)
# 61  0.038680                  (setup)
# 62  0.011377                 (signal)
# 63  0.027304               (software)
# 64  0.010239              (something)
# 65  0.023891                  (speed)
# 66  0.011377                (storage)
# 67  0.051195                (support)
# 68  0.012514                 (switch)
# 69  0.010239                 (system)
# 70  0.010239                   (tech)
# 71  0.012514                  (thing)
# 72  0.038680                   (time)
# 73  0.011377                   (type)
# 74  0.013652                   (unit)
# 75  0.025028                    (use)
# 76  0.017065                (version)
# 77  0.011377                  (video)
# 78  0.010239                    (way)
# 79  0.015927                 (window)
# 80  0.035267               (wireless)
# 81  0.038680                   (work)
# 82  0.022753                   (year)
# 83  0.014790          (access, point)
# 84  0.014790         (access, router)
# 85  0.013652            (ip, address)
# 86  0.010239       (computer, router)
# 87  0.010239   (connection, internet)
# 88  0.010239            (lrb, router)
# 89  0.036405               (lrb, rrb)
# 90  0.015927          (modem, router)
# 91  0.010239        (network, router)
# 92  0.010239           (network, rrb)
# 93  0.011377          (point, router)
# 94  0.022753            (router, rrb)
# 95  0.011377         (router, switch)
# 96  0.011377           (time, router)
# 97  0.014790       (wireless, router)
# 98  0.015927           (router, year)
# 99  0.010239  (access, point, router) frequent_itemsets
#      support             itemsets
# 0   0.011611           (anything)
# 1   0.010160                (bar)
# 2   0.036284               (bass)
# 3   0.015965            (battery)
# 4   0.013062                (bit)
# 5   0.011611             (button)
# 6   0.013062              (cable)
# 7   0.036284           (computer)
# 8   0.020319            (control)
# 9   0.023222             (device)
# 10  0.010160               (dock)
# 11  0.023222               (home)
# 12  0.010160              (house)
# 13  0.010160              (input)
# 14  0.011611               (ipod)
# 15  0.011611              (issue)
# 16  0.011611               (item)
# 17  0.013062                (jbl)
# 18  0.017417              (level)
# 19  0.014514               (line)
# 20  0.010160               (look)
# 21  0.010160                (lot)
# 22  0.047896                (lrb)
# 23  0.010160              (money)
# 24  0.046444              (music)
# 25  0.024673                 (nt)
# 26  0.010160             (office)
# 27  0.011611               (pair)
# 28  0.011611             (people)
# 29  0.010160              (phone)
# 30  0.020319             (player)
# 31  0.013062              (power)
# 32  0.026125              (price)
# 33  0.015965            (problem)
# 34  0.026125            (product)
# 35  0.013062           (purchase)
# 36  0.059507            (quality)
# 37  0.010160              (radio)
# 38  0.018868             (review)
# 39  0.029028               (room)
# 40  0.060958                (rrb)
# 41  0.014514                (set)
# 42  0.017417               (size)
# 43  0.015965          (something)
# 44  0.103048              (sound)
# 45  0.252540            (speaker)
# 46  0.014514                (sub)
# 47  0.011611          (subwoofer)
# 48  0.013062           (surround)
# 49  0.049347             (system)
# 50  0.014514            (theater)
# 51  0.031930              (thing)
# 52  0.020319               (time)
# 53  0.014514                 (tv)
# 54  0.033382               (unit)
# 55  0.044993                (use)
# 56  0.047896             (volume)
# 57  0.014514                (way)
# 58  0.020319               (work)
# 59  0.014514               (year)
# 60  0.010160      (bass, speaker)
# 61  0.026125  (computer, speaker)
# 62  0.013062      (home, speaker)
# 63  0.034833           (lrb, rrb)
# 64  0.018868       (lrb, speaker)
# 65  0.010160         (music, rrb)
# 66  0.015965     (sound, quality)
# 67  0.015965   (speaker, quality)
# 68  0.023222       (speaker, rrb)
# 69  0.027576     (sound, speaker)
# 70  0.010160      (sound, system)
# 71  0.011611      (sound, volume)
# 72  0.017417    (system, speaker)
# 73  0.011611      (unit, speaker)
# 74  0.018868       (speaker, use)
# 75  0.010160    (volume, speaker)
# 76  0.010160  (speaker, lrb, rrb) frequent_itemsets
#      support             itemsets
# 0   0.015686           (anything)
# 1   0.070588              (apple)
# 2   0.094118            (battery)
# 3   0.013725                (buy)
# 4   0.013725           (capacity)
# 5   0.013725                (car)
# 6   0.021569               (case)
# 7   0.033333                 (cd)
# 8   0.029412             (charge)
# 9   0.017647              (click)
# 10  0.033333           (computer)
# 11  0.015686                (con)
# 12  0.017647                (day)
# 13  0.019608             (design)
# 14  0.027451             (device)
# 15  0.017647              (drive)
# 16  0.019608         (everything)
# 17  0.013725         (experience)
# 18  0.013725               (fact)
# 19  0.021569            (feature)
# 20  0.023529               (file)
# 21  0.017647               (game)
# 22  0.021569                 (gb)
# 23  0.013725         (generation)
# 24  0.029412               (hour)
# 25  0.229412               (ipod)
# 26  0.013725             (iriver)
# 27  0.050980             (itunes)
# 28  0.019608               (life)
# 29  0.019608               (look)
# 30  0.043137                (lot)
# 31  0.011765                (mac)
# 32  0.019608             (market)
# 33  0.013725               (mini)
# 34  0.013725              (model)
# 35  0.013725              (money)
# 36  0.031373              (month)
# 37  0.039216                (mp3)
# 38  0.080392              (music)
# 39  0.011765               (need)
# 40  0.035294                 (nt)
# 41  0.015686                 (pc)
# 42  0.017647             (people)
# 43  0.011765              (photo)
# 44  0.015686               (play)
# 45  0.088235             (player)
# 46  0.011765              (price)
# 47  0.019608            (problem)
# 48  0.039216            (product)
# 49  0.011765            (program)
# 50  0.013725           (purchase)
# 51  0.027451            (quality)
# 52  0.015686            (scratch)
# 53  0.045098            (service)
# 54  0.027451           (software)
# 55  0.013725          (something)
# 56  0.056863               (song)
# 57  0.017647              (sound)
# 58  0.015686            (storage)
# 59  0.011765              (store)
# 60  0.049020              (thing)
# 61  0.050980               (time)
# 62  0.011765               (unit)
# 63  0.050980                (use)
# 64  0.013725               (user)
# 65  0.015686                (way)
# 66  0.011765               (week)
# 67  0.023529              (wheel)
# 68  0.011765             (window)
# 69  0.019608               (work)
# 70  0.025490               (year)
# 71  0.013725                (zen)
# 72  0.013725     (battery, apple)
# 73  0.017647        (ipod, apple)
# 74  0.011765     (product, apple)
# 75  0.017647      (hour, battery)
# 76  0.021569      (ipod, battery)
# 77  0.017647      (life, battery)
# 78  0.015686      (battery, year)
# 79  0.015686       (hour, charge)
# 80  0.015686       (wheel, click)
# 81  0.013725     (ipod, computer)
# 82  0.013725   (itunes, computer)
# 83  0.011765         (file, ipod)
# 84  0.011765         (hour, ipod)
# 85  0.021569       (ipod, itunes)
# 86  0.013725          (ipod, mp3)
# 87  0.021569        (music, ipod)
# 88  0.013725           (ipod, nt)
# 89  0.023529       (player, ipod)
# 90  0.011765     (software, ipod)
# 91  0.023529          (ipod, use)
# 92  0.017647   (software, itunes)
# 93  0.037255        (player, mp3)
# 94  0.013725  (player, mp3, ipod) frequent_itemsets
#      support                 itemsets
# 0   0.035211              (antivirus)
# 1   0.016432               (anything)
# 2   0.011737                    (buy)
# 3   0.011737              (component)
# 4   0.089202               (computer)
# 5   0.016432                   (cost)
# 6   0.018779               (customer)
# 7   0.014085                    (day)
# 8   0.011737                (edition)
# 9   0.011737                  (error)
# 10  0.011737             (experience)
# 11  0.021127                (feature)
# 12  0.018779                   (file)
# 13  0.035211               (firewall)
# 14  0.011737                   (help)
# 15  0.016432                   (home)
# 16  0.011737                   (hour)
# 17  0.011737                (install)
# 18  0.021127           (installation)
# 19  0.014085            (instruction)
# 20  0.051643               (internet)
# 21  0.011737                    (lot)
# 22  0.018779                 (memory)
# 23  0.016432                 (minute)
# 24  0.016432                  (month)
# 25  0.023474                     (ni)
# 26  0.075117                 (norton)
# 27  0.025822                     (nt)
# 28  0.014085                 (number)
# 29  0.021127                     (pc)
# 30  0.014085                 (people)
# 31  0.086854                (problem)
# 32  0.110329                (product)
# 33  0.084507                (program)
# 34  0.023474                 (review)
# 35  0.084507               (security)
# 36  0.016432                (service)
# 37  0.023474                   (site)
# 38  0.051643               (software)
# 39  0.011737           (subscription)
# 40  0.035211                (support)
# 41  0.018779               (symantec)
# 42  0.037559                 (system)
# 43  0.023474            (systemworks)
# 44  0.014085                  (thing)
# 45  0.046948                   (time)
# 46  0.011737                (trouble)
# 47  0.014085                 (update)
# 48  0.014085                    (use)
# 49  0.065728                (version)
# 50  0.021127                    (way)
# 51  0.021127                 (window)
# 52  0.032864                   (work)
# 53  0.023474                   (year)
# 54  0.011737    (antivirus, security)
# 55  0.021127      (problem, computer)
# 56  0.014085          (file, program)
# 57  0.042254     (security, internet)
# 58  0.011737        (problem, norton)
# 59  0.018779        (norton, product)
# 60  0.011737          (time, product)
# 61  0.014085      (program, security)
# 62  0.011737     (software, security)
# 63  0.014085       (system, security)
# 64  0.011737  (systemworks, security)
# 65  0.014085      (security, version) frequent_itemsets
# Frequent itemsets for Apex AD2600 Progressive-scan DVD player:
#      support             itemsets
# 8   0.010727            (control)
# 21  0.010727                (lot)
# 5   0.010727                (buy)
# 12  0.010727               (disk)
# 45  0.010727                (try)
# 38  0.011919             (return)
# 46  0.011919                 (tv)
# 41  0.011919          (something)
# 42  0.011919            (support)
# 50  0.011919                (way)
# 17  0.013111             (format)
# 6   0.013111                 (cd)
# 27  0.013111             (number)
# 35  0.013111           (purchase)
# 23  0.014303              (model)
# 28  0.014303             (output)
# 19  0.014303               (gift)
# 65  0.014303  (player, apex, dvd)
# 48  0.014303                (use)
# 37  0.014303             (remote)
# 13  0.015495            (display)
# 54  0.015495          (apex, dvd)
# 3   0.015495              (brand)
# 55  0.016687       (player, apex)
# 18  0.016687                (get)
# 62  0.017878       (player, play)
# 1   0.017878             (amazon)
# 22  0.020262            (machine)
# 39  0.020262             (review)
# 51  0.021454               (week)
# 58  0.021454          (dvd, play)
# 0   0.021454             (ad2600)
# 10  0.021454                (day)
# 56  0.022646  (service, customer)
# 7   0.022646          (christmas)
# 26  0.023838              (movie)
# 43  0.023838              (thing)
# 49  0.023838              (video)
# 4   0.025030             (button)
# 36  0.025030            (quality)
# 11  0.026222               (disc)
# 40  0.026222            (service)
# 24  0.026222              (money)
# 9   0.027414           (customer)
# 34  0.027414            (product)
# 44  0.027414               (time)
# 52  0.029797               (work)
# 25  0.033373              (month)
# 16  0.035757            (feature)
# 32  0.035757              (price)
# 47  0.035757               (unit)
# 29  0.036949            (picture)
# 2   0.060787               (apex)
# 59  0.108462        (player, dvd)
#
#
# Frequent itemsets for Canon G3:
#      support            itemsets
# 3   0.010903               (buy)
# 58  0.010903              (view)
# 54  0.010903             (store)
# 53  0.010903         (something)
# 51  0.010903               (slr)
# 10  0.010903               (day)
# 11  0.010903        (everything)
# 46  0.010903            (screen)
# 42  0.010903          (research)
# 17  0.010903             (focus)
# 21  0.010903              (hand)
# 0   0.012461              (auto)
# 68  0.012461      (film, camera)
# 61  0.012461              (work)
# 30  0.012461             (month)
# 23  0.012461               (lcd)
# 34  0.012461       (photography)
# 2   0.012461            (button)
# 7   0.012461            (choice)
# 20  0.012461               (get)
# 84  0.014019    (image, quality)
# 65  0.014019     (life, battery)
# 27  0.014019         (megapixel)
# 60  0.014019               (way)
# 8   0.014019             (color)
# 43  0.014019        (resolution)
# 16  0.015576              (flaw)
# 29  0.015576            (moment)
# 38  0.015576             (price)
# 47  0.017134           (setting)
# 49  0.017134              (shot)
# 13  0.017134              (feel)
# 41  0.017134             (range)
# 86  0.017134      (point, shoot)
# 25  0.017134              (life)
# 26  0.017134               (lot)
# 39  0.017134           (problem)
# 32  0.017134            (option)
# 85  0.020249  (picture, quality)
# 18  0.021807                (g2)
# ...
# 10  0.034985                (cut)
# 64  0.037901     (speed, control)
# 24  0.037901            (machine)
# 33  0.043732              (price)
# 43  0.043732               (tool)
# 32  0.046647              (power)
# 9   0.049563            (control)
# 16  0.052478               (hand)
# 80  0.064140      (router, table)
#
#
# Frequent itemsets for Linksys Router:
#      support             itemsets
# 21  0.011345                (get)
# 46  0.011345              (range)
# 56  0.011345               (star)
# 32  0.011345                (lot)
# 29  0.011345           (internet)
# 57  0.011345               (step)
# 10  0.011345             (couple)
# 15  0.011345           (ethernet)
# 42  0.012966              (price)
# 41  0.012966              (point)
# 36  0.012966               (need)
# 17  0.012966         (experience)
# 16  0.012966         (everything)
# 24  0.012966               (home)
# 13  0.012966      (documentation)
# 12  0.012966             (device)
# 11  0.012966                (day)
# 8   0.012966            (connect)
# 18  0.014587            (feature)
# 19  0.014587               (file)
# 54  0.014587            (someone)
# 22  0.014587           (hardware)
# 70  0.014587       (modem, cable)
# 53  0.014587           (software)
# 40  0.016207             (people)
# 75  0.016207  (network, wireless)
# 45  0.016207            (program)
# 65  0.016207                (way)
# 26  0.016207              (house)
# 23  0.016207               (help)
# 47  0.016207             (review)
# 1   0.016207            (address)
# 2   0.016207                (box)
# 52  0.017828               (site)
# 27  0.017828       (installation)
# 50  0.017828            (service)
# 64  0.017828            (version)
# 14  0.019449         (encryption)
# 7   0.019449      (configuration)
# 4   0.021070               (card)
# 59  0.021070             (system)
# 0   0.022690             (access)
# 3   0.024311              (cable)
# 20  0.027553           (firmware)
# 60  0.027553              (thing)
# 55  0.030794              (speed)
# 58  0.030794            (support)
# 35  0.032415              (modem)
# 80  0.035656   (wireless, router)
# 61  0.038898               (time)
# 49  0.038898           (security)
# 67  0.040519               (work)
# 44  0.043760            (product)
# 9   0.047002         (connection)
# 6   0.050243           (computer)
# 43  0.051864            (problem)
# 66  0.072934           (wireless)
#
#
# Frequent itemsets for MicroMP3:
#      support         itemsets
# 0   0.010377        (ability)
# 63  0.010377           (work)
# 50  0.010377           (size)
# 27  0.010377           (list)
# 12  0.010377       (download)
# 37  0.010377            (pad)
# 4   0.010377          (cable)
# 75  0.011321    (player, use)
# 28  0.011321           (look)
# 5   0.011321           (case)
# 64  0.011321           (year)
# 7   0.011321        (company)
# 19  0.011321           (hand)
# 49  0.012264        (service)
# 55  0.012264        (storage)
# 40  0.012264           (play)
# 57  0.012264        (support)
# 18  0.013208            (get)
# 13  0.014151          (drive)
# 66  0.014151  (life, battery)
# 33  0.014151          (month)
# 9   0.014151            (day)
# 61  0.015094           (week)
# 10  0.015094         (design)
# 29  0.015094            (lot)
# 22  0.016038      (interface)
# 56  0.016038          (store)
# 52  0.016981      (something)
# 3   0.016981         (button)
# 42  0.017925          (price)
# 45  0.018868       (purchase)
# 21  0.018868           (hour)
# 39  0.018868         (people)
# 11  0.019811         (device)
# 26  0.019811           (life)
# 47  0.020755          (radio)
# 8   0.022642       (computer)
# 16  0.022642       (firmware)
# 15  0.026415           (file)
# 48  0.027358         (review)
# 59  0.027358           (time)
# 54  0.028302          (sound)
# 46  0.031132        (quality)
# 20  0.032075      (headphone)
# 58  0.032075          (thing)
# 44  0.033019        (product)
# 43  0.033019        (problem)
# 72  0.033962    (player, mp3)
# 14  0.035849        (feature)
# 51  0.037736       (software)
# 35  0.040566          (music)
# 53  0.043396           (song)
# 71  0.053774     (micro, zen)
# 2   0.055660        (battery)
#
#
# Frequent itemsets for Nikon coolpix 4300:
#      support            itemsets
# 41  0.010526             (power)
# 97  0.010526      (point, shoot)
# 45  0.010526          (purchase)
# 26  0.010526                (mb)
# 25  0.010526              (love)
# 19  0.010526               (get)
# 58  0.010526               (slr)
# 40  0.010526             (point)
# 60  0.010526             (speed)
# 16  0.010526              (film)
# 13  0.010526        (everything)
# 61  0.010526             (store)
# 64  0.010526            (travel)
# 6   0.010526               (cap)
# 68  0.010526              (work)
# 92  0.010526      (reader, card)
# 14  0.010526        (experience)
# 36  0.010526                (pc)
# 51  0.013158              (room)
# 48  0.013158            (reader)
# 47  0.013158             (range)
# 90  0.013158      (memory, card)
# 0   0.013158           (adapter)
# 32  0.013158             (movie)
# 3   0.013158          (beginner)
# 35  0.013158            (option)
# 22  0.013158              (lens)
# 18  0.013158             (flash)
# 98  0.013158      (price, range)
# 5   0.015789             (canon)
# 67  0.015789              (week)
# 50  0.015789            (review)
# 30  0.015789             (money)
# 71  0.018421     (life, battery)
# 66  0.018421               (way)
# 43  0.018421             (print)
# 11  0.018421               (day)
# 27  0.021053            (memory)
# 23  0.021053              (life)
# 10  0.021053           (coolpix)
# 24  0.021053               (lot)
# 59  0.021053          (software)
# 53  0.023684           (setting)
# 29  0.023684             (model)
# 69  0.023684              (zoom)
# 44  0.028947           (problem)
# 95  0.028947  (picture, quality)
# 42  0.028947             (price)
# 63  0.034211              (time)
# 15  0.034211           (feature)
# 57  0.034211              (size)
# 2   0.068421           (battery)
# 39  0.134211           (picture)
#
#
# Frequent itemsets for Nokia 6600:
#      support          itemsets
# 61  0.011609     (phone, cell)
# 23  0.011609            (menu)
# 17  0.011609            (hour)
# 26  0.011609            (need)
# 68  0.013267  (phone, speaker)
# 24  0.013267         (message)
# 37  0.013267          (rebate)
# 39  0.013267          (repair)
# 56  0.013267            (year)
# 46  0.013267         (support)
# 47  0.013267          (system)
# 7   0.013267           (color)
# 6   0.013267            (cell)
# 51  0.013267        (transfer)
# 2   0.013267       (bluetooth)
# 13  0.013267      (everything)
# 54  0.013267             (way)
# 41  0.014925          (second)
# 59  0.014925    (memory, card)
# 38  0.014925       (reception)
# 27  0.014925           (nokia)
# 18  0.014925       (interface)
# 43  0.016584            (size)
# 25  0.016584           (month)
# 57  0.016584   (life, battery)
# 10  0.016584         (contact)
# 12  0.018242          (device)
# 42  0.018242         (service)
# 34  0.018242         (picture)
# 21  0.018242             (lot)
# 60  0.019900     (card, phone)
# 29  0.021559          (number)
# 3   0.021559            (call)
# 35  0.021559         (problem)
# 20  0.023217            (life)
# 22  0.023217          (memory)
# 53  0.023217           (video)
# 32  0.023217          (people)
# 48  0.024876           (thing)
# 9   0.024876        (computer)
# 70  0.026534      (phone, use)
# 40  0.028192          (screen)
# 1   0.028192         (battery)
# 49  0.034826            (time)
# 14  0.053068         (feature)
# 52  0.054726             (use)
#
#
# Frequent itemsets for Nokia 6610:
#      support          itemsets
# 29  0.010221          (pocket)
# 1   0.010221            (area)
# 52  0.010221            (week)
# 8   0.010221        (customer)
# 26  0.010221          (person)
# 22  0.010221           (music)
# 12  0.010221              (fm)
# 18  0.010221             (key)
# 15  0.010221         (headset)
# 17  0.010221        (internet)
# 58  0.011925     (phone, cell)
# 59  0.011925   (color, screen)
# 0   0.011925          (access)
# 76  0.011925  (sound, quality)
# 10  0.011925           (email)
# 51  0.013629             (way)
# 13  0.013629        (function)
# 50  0.015332          (volume)
# 41  0.015332           (sound)
# 36  0.015332         (samsung)
# 23  0.015332          (number)
# 9   0.017036             (day)
# 20  0.017036             (lot)
# 35  0.017036       (ringtones)
# 28  0.018739            (plan)
# 25  0.018739          (people)
# 6   0.020443           (color)
# 21  0.020443            (menu)
# 55  0.020443   (life, battery)
# 49  0.022147           (voice)
# 53  0.022147            (work)
# 39  0.022147            (size)
# 30  0.022147         (problem)
# 43  0.022147           (thing)
# 34  0.022147       (reception)
# 44  0.023850            (time)
# 19  0.023850            (life)
# 37  0.025554          (screen)
# 24  0.027257          (option)
# 42  0.027257    (speakerphone)
# 2   0.028961         (battery)
# 33  0.035775           (radio)
# 31  0.035775         (quality)
# 38  0.051107         (service)
# 11  0.073254         (feature)
#
#
# Frequent itemsets for Router:
#      support                itemsets
# 1   0.010239               (adapter)
# 55  0.010239                (review)
# 25  0.010239          (installation)
# 64  0.010239             (something)
# 69  0.010239                (system)
# 70  0.010239                  (tech)
# 18  0.010239              (ethernet)
# 44  0.010239                (people)
# 5   0.010239                   (buy)
# 87  0.010239  (connection, internet)
# 78  0.010239                   (way)
# 49  0.011377                 (price)
# 13  0.011377               (desktop)
# 73  0.011377                  (type)
# 33  0.011377                  (mbps)
# 45  0.011377                 (phone)
# 6   0.011377                 (cable)
# 66  0.011377               (storage)
# 77  0.011377                 (video)
# 30  0.011377                  (line)
# 62  0.011377                (signal)
# 28  0.011377                 (issue)
# 58  0.012514              (security)
# 71  0.012514                 (thing)
# 17  0.012514                 (drive)
# 7   0.013652                (change)
# 19  0.013652            (everything)
# 54  0.013652           (replacement)
# 11  0.013652                   (day)
# 29  0.013652                (laptop)
# 74  0.013652                  (unit)
# 83  0.014790         (access, point)
# 97  0.014790      (wireless, router)
# 79  0.015927                (window)
# 20  0.015927               (feature)
# 90  0.015927         (modem, router)
# 60  0.015927               (setting)
# 35  0.015927                 (model)
# 10  0.017065              (customer)
# 76  0.017065               (version)
# 22  0.017065                  (home)
# 50  0.017065               (printer)
# 48  0.017065                 (power)
# 59  0.018203               (service)
# 42  0.018203              (password)
# 41  0.018203                (number)
# 23  0.019340                  (hour)
# 3   0.019340                   (box)
# 53  0.020478                 (range)
# 31  0.020478               (linksys)
# 46  0.020478                 (point)
# 2   0.020478               (address)
# 24  0.020478                 (house)
# 37  0.021615                 (month)
# 82  0.022753                  (year)
# 47  0.022753                  (port)
# 36  0.022753                 (modem)
# 65  0.023891                 (speed)
# 26  0.025028              (internet)
# 75  0.025028                   (use)
# 63  0.027304              (software)
# 80  0.035267              (wireless)
# 21  0.036405              (firmware)
# 8   0.036405              (computer)
# 9   0.038680            (connection)
# 14  0.038680                (device)
# 72  0.038680                  (time)
# 81  0.038680                  (work)
# 61  0.038680                 (setup)
# 52  0.046644               (product)
# 67  0.051195               (support)
# 51  0.053470               (problem)
# 38  0.058020               (network)
#
#
# Frequent itemsets for Speaker:
#      support             itemsets
# 20  0.010160               (look)
# 1   0.010160                (bar)
# 37  0.010160              (radio)
# 70  0.010160      (sound, system)
# 29  0.010160              (phone)
# 10  0.010160               (dock)
# 26  0.010160             (office)
# 12  0.010160              (house)
# 13  0.010160              (input)
# 23  0.010160              (money)
# 21  0.010160                (lot)
# 47  0.011611          (subwoofer)
# 28  0.011611             (people)
# 27  0.011611               (pair)
# 0   0.011611           (anything)
# 15  0.011611              (issue)
# 14  0.011611               (ipod)
# 5   0.011611             (button)
# 16  0.011611               (item)
# 6   0.013062              (cable)
# 35  0.013062           (purchase)
# 48  0.013062           (surround)
# 4   0.013062                (bit)
# 31  0.013062              (power)
# 46  0.014514                (sub)
# 50  0.014514            (theater)
# 59  0.014514               (year)
# 57  0.014514                (way)
# 19  0.014514               (line)
# 41  0.014514                (set)
# 33  0.015965            (problem)
# 3   0.015965            (battery)
# 43  0.015965          (something)
# 66  0.015965     (sound, quality)
# 42  0.017417               (size)
# 72  0.017417    (system, speaker)
# 18  0.017417              (level)
# 38  0.018868             (review)
# 52  0.020319               (time)
# 58  0.020319               (work)
# 8   0.020319            (control)
# 30  0.020319             (player)
# 11  0.023222               (home)
# 9   0.023222             (device)
# 34  0.026125            (product)
# 32  0.026125              (price)
# 61  0.026125  (computer, speaker)
# 39  0.029028               (room)
# 51  0.031930              (thing)
# 54  0.033382               (unit)
# 24  0.046444              (music)
# 49  0.049347             (system)
#
#
# Frequent itemsets for ipod:
#      support         itemsets
# 66  0.011765           (week)
# 62  0.011765           (unit)
# 59  0.011765          (store)
# 39  0.011765           (need)
# 49  0.011765        (program)
# 55  0.013725      (something)
# 23  0.013725     (generation)
# 35  0.013725          (money)
# 18  0.013725           (fact)
# 17  0.013725     (experience)
# 33  0.013725           (mini)
# 34  0.013725          (model)
# 64  0.013725           (user)
# 5   0.013725            (car)
# 3   0.013725            (buy)
# 50  0.013725       (purchase)
# 44  0.015686           (play)
# 58  0.015686        (storage)
# 65  0.015686            (way)
# 0   0.015686       (anything)
# 80  0.015686   (wheel, click)
# 21  0.017647           (game)
# 77  0.017647  (life, battery)
# 42  0.017647         (people)
# 15  0.017647          (drive)
# 9   0.017647          (click)
# 57  0.017647          (sound)
# 12  0.017647            (day)
# 32  0.019608         (market)
# 29  0.019608           (look)
# 28  0.019608           (life)
# 69  0.019608           (work)
# 16  0.019608     (everything)
# 47  0.019608        (problem)
# 13  0.019608         (design)
# 6   0.021569           (case)
# 67  0.023529          (wheel)
# 54  0.027451       (software)
# 51  0.027451        (quality)
# 14  0.027451         (device)
# 8   0.029412         (charge)
# 36  0.031373          (month)
# 10  0.033333       (computer)
# 48  0.039216        (product)
# 30  0.043137            (lot)
# 53  0.045098        (service)
# 60  0.049020          (thing)
# 61  0.050980           (time)
# 56  0.056863           (song)
# 1   0.070588          (apple)
# 38  0.080392          (music)
# 2   0.094118        (battery)
#
#
# Frequent itemsets for norton:
#      support        itemsets
# 2   0.011737           (buy)
# 9   0.011737         (error)
# 10  0.011737    (experience)
# 14  0.011737          (help)
# 17  0.011737       (install)
# 21  0.011737           (lot)
# 7   0.014085           (day)
# 44  0.014085         (thing)
# 48  0.014085           (use)
# 47  0.014085        (update)
# 30  0.014085        (people)
# 28  0.014085        (number)
# 15  0.016432          (home)
# 1   0.016432      (anything)
# 5   0.016432          (cost)
# 36  0.016432       (service)
# 22  0.018779        (memory)
# 6   0.018779      (customer)
# 41  0.018779      (symantec)
# 18  0.021127  (installation)
# 11  0.021127       (feature)
# 50  0.021127           (way)
# 37  0.023474          (site)
# 34  0.023474        (review)
# 52  0.032864          (work)
# 13  0.035211      (firewall)
# 40  0.035211       (support)
# 0   0.035211     (antivirus)
# 45  0.046948          (time)
# 49  0.065728       (version)
# 33  0.084507       (program)
# 32  0.110329       (product)

# %%
pd.set_option('display.max_row', 100)
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from collections import defaultdict

def extract_potential_features(pos_tagged_reviews):
    return [[word for word, pos in review if pos.startswith('NN') or pos.startswith('NG')] for review in pos_tagged_reviews]

# Initialize a dictionary to hold the original frequent itemsets DataFrames for each product
original_frequent_features_dict = {}

for product_name, group in df_product_reviews.groupby('product'):
    reviews_df = group['review_preprocessed'].tolist()
    reviews = extract_potential_features(reviews_df)
    
    te = TransactionEncoder()
    te_ary = te.fit(reviews).transform(reviews)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    
    frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
    
    # Store the original frequent itemsets DataFrame in the dictionary
    original_frequent_features_dict[product_name] = frequent_itemsets
    
original_frequent_features_dict
# Out:
# {'Apex AD2600 Progressive-scan DVD player':       support                itemsets
#  0    0.880810                      ()
#  1    0.021454                (ad2600)
#  2    0.017878                (amazon)
#  3    0.060787                  (apex)
#  4    0.015495                 (brand)
#  ..        ...                     ...
#  126  0.014303     (player, apex, dvd)
#  127  0.013111     (player, dvd, play)
#  128  0.011919  (problem, player, dvd)
#  129  0.011919   (, player, apex, dvd)
#  130  0.011919   (, player, dvd, play)
#
#  [131 rows x 2 columns],
#  'Canon G3':       support               itemsets
#  0    0.809969                     ()
#  1    0.012461                 (auto)
#  2    0.035826              (battery)
#  3    0.012461               (button)
#  4    0.010903                  (buy)
#  ..        ...                    ...
#  162  0.012461     (, image, quality)
#  163  0.018692   (, picture, quality)
#  164  0.014019       (, point, shoot)
#  165  0.014019    (camera, g3, canon)
#  166  0.014019  (, camera, g3, canon)
#
#  [167 rows x 2 columns],
#  'Canon PowerShot SD500':       support                          itemsets
#  0    0.878261                                ()
#  1    0.017391                            (auto)
#  2    0.013043                         (balance)
#  3    0.026087                         (battery)
#  4    0.017391                             (bit)
#  ..        ...                               ...
#  217  0.013043        (, thing, camera, quality)
#  218  0.017391        (, video, camera, quality)
#  219  0.013043          (, video, clip, quality)
#  220  0.013043    (video, camera, clip, quality)
#  221  0.013043  (, video, clip, quality, camera)
#
#  [222 rows x 2 columns],
#  'Canon S100':       support                      itemsets
#  0    0.722063                            ()
#  1    0.011461                     (balance)
#  2    0.065903                     (battery)
#  3    0.014327                      (button)
#  4    0.320917                      (camera)
#  ..        ...                           ...
#  155  0.011461        (camera, point, shoot)
#  156  0.011461         (memory, thing, card)
#  157  0.011461     (, case, camera, battery)
#  158  0.011461  (, picture, camera, quality)
#  159  0.011461       (, card, thing, memory)
#
#  [160 rows x 2 columns],
#  'Computer':       support              itemsets
#  0    0.883239                    ()
#  1    0.054614                (acer)
#  2    0.020716               (apple)
#  3    0.016949               (brand)
#  4    0.011299               (cable)
#  ..        ...                   ...
#  129  0.022599          (, lrb, rrb)
#  130  0.022599    (, price, monitor)
#  131  0.011299  (, problem, monitor)
#  132  0.013183      (, monitor, rrb)
#  133  0.015066   (, monitor, screen)
#
#  [134 rows x 2 columns],
#  'Creative Labs Nomad Jukebox Zen Xtra 40GB':       support              itemsets
#  0    0.877968                    ()
#  1    0.012700               (album)
#  2    0.013805               (apple)
#  3    0.042518             (battery)
#  4    0.023744              (button)
#  ..        ...                   ...
#  130  0.030922       (, player, mp3)
#  131  0.012700     (, music, player)
#  132  0.012700  (, player, software)
#  133  0.011044     (, software, use)
#  134  0.014909         (, xtra, zen)
#
#  [135 rows x 2 columns],
#  'Diaper Champ':       support                 itemsets
#  0    0.712264                       ()
#  1    0.047170                   (baby)
#  2    0.172170                    (bag)
#  3    0.136792                  (champ)
#  4    0.028302                 (change)
#  ..        ...                      ...
#  155  0.011792   (, bag, diaper, champ)
#  156  0.011792   (, bag, diaper, genie)
#  157  0.014151   (, bag, diaper, trash)
#  158  0.011792      (, bag, use, trash)
#  159  0.011792  (, odor, diaper, champ)
#
#  [160 rows x 2 columns],
#  'Hitachi router':       support                itemsets
#  0    0.778426                      ()
#  1    0.011662                (action)
#  2    0.046647            (adjustment)
#  3    0.014577                (amazon)
#  4    0.011662                  (base)
#  ..        ...                     ...
#  153  0.032070         (, router, use)
#  154  0.011662        (, router, year)
#  155  0.020408          (, use, table)
#  156  0.017493    (use, router, table)
#  157  0.017493  (, use, router, table)
#
#  [158 rows x 2 columns],
#  'Linksys Router':       support              itemsets
#  0    0.813614                    ()
#  1    0.022690              (access)
#  2    0.016207             (address)
#  3    0.016207                 (box)
#  4    0.024311               (cable)
#  ..        ...                   ...
#  155  0.014587  (, router, security)
#  156  0.014587     (, setup, router)
#  157  0.012966       (, router, use)
#  158  0.035656  (, wireless, router)
#  159  0.011345      (, work, router)
#
#  [160 rows x 2 columns],
#  'MicroMP3':       support             itemsets
#  0    0.869811                   ()
#  1    0.010377            (ability)
#  2    0.021698              (apple)
#  3    0.055660            (battery)
#  4    0.016981             (button)
#  ..        ...                  ...
#  145  0.031132      (, player, mp3)
#  146  0.013208  (, problem, player)
#  147  0.011321     (, song, player)
#  148  0.011321      (, player, use)
#  149  0.010377      (, zen, player)
#
#  [150 rows x 2 columns],
#  'Nikon coolpix 4300':       support                      itemsets
#  0    0.778947                            ()
#  1    0.013158                     (adapter)
#  2    0.013158                        (auto)
#  3    0.068421                     (battery)
#  4    0.013158                    (beginner)
#  ..        ...                           ...
#  186  0.013158             (, picture, size)
#  187  0.010526              (, price, range)
#  188  0.015789             (, size, quality)
#  189  0.010526    (picture, camera, quality)
#  190  0.010526  (, picture, camera, quality)
#
#  [191 rows x 2 columns],
#  'Nokia 6600':       support            itemsets
#  0    0.807629                  ()
#  1    0.014925       (application)
#  2    0.028192           (battery)
#  3    0.013267         (bluetooth)
#  4    0.021559              (call)
#  ..        ...                 ...
#  131  0.013267   (, phone, screen)
#  132  0.013267  (, phone, speaker)
#  133  0.013267     (, time, phone)
#  134  0.026534      (, phone, use)
#  135  0.014925     (, work, phone)
#
#  [136 rows x 2 columns],
#  'Nokia 6610':       support              itemsets
#  0    0.890971                    ()
#  1    0.011925              (access)
#  2    0.010221                (area)
#  3    0.028961             (battery)
#  4    0.010221              (button)
#  ..        ...                   ...
#  143  0.011925      (, voice, phone)
#  144  0.010221       (, work, phone)
#  145  0.010221       (, phone, year)
#  146  0.010221    (, sound, quality)
#  147  0.010221  (, service, tmobile)
#
#  [148 rows x 2 columns],
#  'Router':       support                 itemsets
#  0    0.861206                       ()
#  1    0.025028                 (access)
#  2    0.010239                (adapter)
#  3    0.020478                (address)
#  4    0.019340                    (box)
#  ..        ...                      ...
#  178  0.010239       (, router, switch)
#  179  0.010239         (, time, router)
#  180  0.013652     (, wireless, router)
#  181  0.011377         (, router, year)
#  182  0.010239  (access, point, router)
#
#  [183 rows x 2 columns],
#  'Speaker':       support               itemsets
#  0    0.875181                     ()
#  1    0.011611             (anything)
#  2    0.010160                  (bar)
#  3    0.036284                 (bass)
#  4    0.015965              (battery)
#  ..        ...                    ...
#  143  0.010160      (, unit, speaker)
#  144  0.018868       (, speaker, use)
#  145  0.010160    (, volume, speaker)
#  146  0.010160    (speaker, lrb, rrb)
#  147  0.010160  (, speaker, lrb, rrb)
#
#  [148 rows x 2 columns],
#  'ipod':       support               itemsets
#  0    0.898039                     ()
#  1    0.015686             (anything)
#  2    0.070588                (apple)
#  3    0.094118              (battery)
#  4    0.013725                  (buy)
#  ..        ...                    ...
#  182  0.021569          (, ipod, use)
#  183  0.017647   (, itunes, software)
#  184  0.035294        (, player, mp3)
#  185  0.013725    (ipod, mp3, player)
#  186  0.011765  (, player, mp3, ipod)
#
#  [187 rows x 2 columns],
#  'norton':       support                itemsets
#  0    0.758216                      ()
#  1    0.035211             (antivirus)
#  2    0.016432              (anything)
#  3    0.011737                   (buy)
#  4    0.011737             (component)
#  ..        ...                     ...
#  115  0.035211  (, security, internet)
#  116  0.014085     (, norton, product)
#  117  0.014085   (, program, security)
#  118  0.014085    (, system, security)
#  119  0.014085   (, security, version)
#
#  [120 rows x 2 columns]}

# %% [markdown]
# ## Compactness Pruning

# %%
# Initialize a dictionary to hold the compactness-pruned frequent itemsets DataFrames
compactness_pruned_features_dict = {}

# Compactness Pruning Process
for product_name, frequent_itemsets in original_frequent_features_dict.items():
    
    frequent_items = frequent_itemsets['itemsets'].tolist()
    frequent_compact_items = defaultdict(lambda: 0)
    
    group = df_product_reviews[df_product_reviews['product'] == product_name]
    reviews = group['review'].tolist()
    reviews = [review.split() for review in reviews]
    
    for ind, review in enumerate(reviews):
        for items in frequent_items:
            index_of_items = []
            for item in items:
                if item in review:
                    index_of_items.append(review.index(item))
            if len(index_of_items) == len(items) and max(index_of_items) - min(index_of_items) < 3:
                frequent_compact_items[items] += 1
    
    # Prune items that appear less frequently
    result_items = [item for item, val in frequent_compact_items.items() if val > 2]
    
    # Handle multi-word items and their partial support
    multi_word_item = {}
    for item, val in frequent_compact_items.items():
        if len(item) > 1:
           multi_word_item[item] = val
           
    p_support = defaultdict(lambda:[])
    for item, val in multi_word_item.items():
        for itm in item:
            p_support[itm].append(val)
    
    min_p_support = 3
    for item, counts in p_support.items():
        if min(counts) <= min_p_support and frozenset([item]) in result_items:
            result_items.remove(frozenset([item]))
    
    # Update the frequent_itemsets DataFrame to keep only the pruned itemsets
    pruned_itemsets = frequent_itemsets[frequent_itemsets['itemsets'].isin(result_items)]
    
    # Store the pruned itemsets DataFrame in the separate dictionary
    compactness_pruned_features_dict[product_name] = pruned_itemsets
    
    # Tagging logic: tag the reviews with the pruned itemsets
    tags = []
    for review in reviews:
        tag = []
        for items in result_items:
            count = 0
            for item in items:
                if item in review:
                    count += 1
            if count == len(items):
                tag.append(items)
        tags.append(tag)
    
    # Update the original DataFrame with the tags
    # df_product_reviews.loc[df_product_reviews['product'] == product_name, 'tags'] = tags
compactness_pruned_features_dict['Apex AD2600 Progressive-scan DVD player']
# Out:
#       support             itemsets
# 1    0.021454             (ad2600)
# 2    0.017878             (amazon)
# 3    0.060787               (apex)
# 4    0.015495              (brand)
# 5    0.025030             (button)
# 6    0.010727                (buy)
# 7    0.013111                 (cd)
# 8    0.022646          (christmas)
# 9    0.010727            (control)
# 10   0.027414           (customer)
# 11   0.021454                (day)
# 12   0.026222               (disc)
# 13   0.010727               (disk)
# 14   0.015495            (display)
# 17   0.035757            (feature)
# 18   0.013111             (format)
# 19   0.016687                (get)
# 20   0.014303               (gift)
# 22   0.010727                (lot)
# 23   0.020262            (machine)
# 24   0.014303              (model)
# 25   0.026222              (money)
# 26   0.033373              (month)
# 27   0.023838              (movie)
# 28   0.013111             (number)
# 29   0.014303             (output)
# 30   0.036949            (picture)
# 33   0.035757              (price)
# 35   0.027414            (product)
# 36   0.013111           (purchase)
# 37   0.025030            (quality)
# 38   0.014303             (remote)
# 39   0.011919             (return)
# 40   0.020262             (review)
# 41   0.026222            (service)
# 42   0.011919          (something)
# 43   0.011919            (support)
# 44   0.023838              (thing)
# 45   0.027414               (time)
# 46   0.010727                (try)
# 47   0.011919                 (tv)
# 48   0.035757               (unit)
# 49   0.014303                (use)
# 50   0.023838              (video)
# 51   0.011919                (way)
# 52   0.021454               (week)
# 53   0.029797               (work)
# 105  0.015495          (apex, dvd)
# 106  0.016687       (player, apex)
# 107  0.022646  (service, customer)
# 109  0.021454          (dvd, play)
# 110  0.108462        (player, dvd)
# 113  0.017878       (player, play)
# 126  0.014303  (player, apex, dvd)

# %% [markdown]
# ## Redundancy Pruning

# %% [markdown]
# The following is a summary of the algorithm described in Hu & Liu (n.d) which was also called redundancy pruning. The purpose of the algorithm in this subsystem is to reduce the number of features with just a single word identified in the Frequent Feature Identification step since many of these will be irrelevant.
#
# We first find the p-support value for each feature found in the Frequent Feature Identification step, which is just a count of the number of times a feature appears in the reviews and titles. A minimum p-support threshold is then set to prune features that fall below the threshold. Then, for each feature that is just a single word - check its p-support value and if it is below the threshold and is a subset of a feature with two or more words in it then it is pruned.

# %%
min_p_support_threshold = 3
redundancy_pruned_compactness_features_dict = {}

for product_name, frequent_itemsets in compactness_pruned_features_dict.items():
    p_support = defaultdict(lambda: 0)
    reviews = df_product_reviews[df_product_reviews['product'] == product_name]['line']
    
    for itemset in frequent_itemsets['itemsets']:
        count = reviews.apply(lambda x: all(word in x for word in itemset)).sum()
        p_support[itemset] = count
    
    pruned_itemsets = []
    multi_word_itemsets = [itemset for itemset in p_support if len(itemset) > 1]
    
    for itemset in p_support:
        if len(itemset) == 1: 
            is_subset = any(itemset.issubset(multi_word_itemset) for multi_word_itemset in multi_word_itemsets)
            if p_support[itemset] < min_p_support_threshold and is_subset:
                continue
        pruned_itemsets.append(itemset)
    
    pruned_itemsets_df = frequent_itemsets[frequent_itemsets['itemsets'].isin(pruned_itemsets)]
    redundancy_pruned_compactness_features_dict[product_name] = pruned_itemsets_df

redundancy_pruned_compactness_features_dict['Apex AD2600 Progressive-scan DVD player']
# Out:
#       support             itemsets
# 1    0.021454             (ad2600)
# 2    0.017878             (amazon)
# 3    0.060787               (apex)
# 4    0.015495              (brand)
# 5    0.025030             (button)
# 6    0.010727                (buy)
# 7    0.013111                 (cd)
# 8    0.022646          (christmas)
# 9    0.010727            (control)
# 10   0.027414           (customer)
# 11   0.021454                (day)
# 12   0.026222               (disc)
# 13   0.010727               (disk)
# 14   0.015495            (display)
# 17   0.035757            (feature)
# 18   0.013111             (format)
# 19   0.016687                (get)
# 20   0.014303               (gift)
# 22   0.010727                (lot)
# 23   0.020262            (machine)
# 24   0.014303              (model)
# 25   0.026222              (money)
# 26   0.033373              (month)
# 27   0.023838              (movie)
# 28   0.013111             (number)
# 29   0.014303             (output)
# 30   0.036949            (picture)
# 33   0.035757              (price)
# 35   0.027414            (product)
# 36   0.013111           (purchase)
# 37   0.025030            (quality)
# 38   0.014303             (remote)
# 39   0.011919             (return)
# 40   0.020262             (review)
# 41   0.026222            (service)
# 42   0.011919          (something)
# 43   0.011919            (support)
# 44   0.023838              (thing)
# 45   0.027414               (time)
# 46   0.010727                (try)
# 47   0.011919                 (tv)
# 48   0.035757               (unit)
# 49   0.014303                (use)
# 50   0.023838              (video)
# 51   0.011919                (way)
# 52   0.021454               (week)
# 53   0.029797               (work)
# 105  0.015495          (apex, dvd)
# 106  0.016687       (player, apex)
# 107  0.022646  (service, customer)
# 109  0.021454          (dvd, play)
# 110  0.108462        (player, dvd)
# 113  0.017878       (player, play)
# 126  0.014303  (player, apex, dvd)

# %% [markdown]
# we then store the redundancy_pruned_compactness_features_dict in the feature set so they can be used later on

# %%
feature_sets = copy.deepcopy(redundancy_pruned_compactness_features_dict)

# %%
tmp1 = df_product_reviews[df_product_reviews['product'] == 'Apex AD2600 Progressive-scan DVD player']
tmp1.loc[6498]
# Out:
# product                          Apex AD2600 Progressive-scan DVD player
# line                   ##before you try to return the player or waste...
# annotated_labels
# review                 before you try to return the player or waste h...
# review_preprocessed    [(try, VB), (return, NN), (player, NN), (waste...
# Name: 6498, dtype: object

# %% [markdown]
# ## Opinion word Extraction

# %% [markdown]
# First I'll need to get all of the frequent features in each review. From there, I'll then need to get

# %%
class OpinionWordExtractor:
    def __init__(self):
        self.feature_sets = feature_sets
        
    def main(self, products, reviews_preprocessed):
        feature_words_in_reviews = self.extract_feature_words_in_reviews(products, reviews_preprocessed)
        {feature: 'x', opinion: 'y'}
        
    def extract_feature_words_in_reviews(self, reviews_preprocessed):
        return reviews_preprocessed.apply(lambda review: [])
        
    def extract_potential_opinion_words(self, reviews_preprocessed):
        return reviews_preprocessed.apply(lambda review: [word for word, pos in review if pos.startswith('JJ')])

# %%
import nltk
from nltk import pos_tag, word_tokenize

class OpinionWordExtractor:
    def __init__(self):
        # Assuming feature_sets is predefined or passed in some way
        self.feature_sets = feature_sets
        
    def main(self, df_product_reviews):
        return df_product_reviews.apply(
            lambda row: self.extract_opinion_words_in_review(
                row['review_preprocessed'], row['product']
            ), axis=1
        )
    
    def extract_opinion_words_in_review(self, review_preprocessed, product):
        feature_words = self.extract_feature_words_in_review(review_preprocessed, product)
        opinion_words = self.extract_potential_opinion_words(review_preprocessed, feature_words)
        
        return opinion_words

    def extract_feature_words_in_review(self, review_preprocessed, product):
        feature_for_product = self.feature_sets[product]['itemsets']
        
        # Convert the review_preprocessed into a list of words for easy matching
        review_words = [word for word, pos in review_preprocessed]
        
        # Find features in the review
        found_features = []
        for itemset in feature_for_product:
            if all(word in review_words for word in itemset):
                found_features.append(' '.join(itemset))

        return found_features

    def extract_potential_opinion_words(self, tagged_tokens, features_in_review):
        opinion_dict = {}
        
        for feature in features_in_review:
            # Find the index of the feature in the tagged tokens
            feature_indices = [i for i, (word, pos) in enumerate(tagged_tokens) if word in feature.split()]
            
            adjectives = []
            for feature_index in feature_indices:
                # Find adjectives (JJ) within a proximity of 3 tokens around the feature
                nearby_adjectives = [word for i, (word, pos) in enumerate(tagged_tokens)
                                     if pos.startswith('JJ') and abs(i - feature_index) <= 3]
                adjectives.extend(nearby_adjectives)
            
            # Add the feature and its associated adjectives to the opinion dictionary
            if adjectives:
                opinion_dict[feature] = adjectives
        
        return opinion_dict

df_product_reviews["opinion_words"] = OpinionWordExtractor().main(df_product_reviews)

df_product_reviews[["product", "review_preprocessed", "opinion_words"]]
# Out:
#                      product  \
# 0                 Nokia 6610
# 1                 Nokia 6610
# 2                 Nokia 6610
# 3                 Nokia 6610
# 4                 Nokia 6610
# ...                      ...
# 10915  Canon PowerShot SD500
# 10916  Canon PowerShot SD500
# 10917  Canon PowerShot SD500
# 10918  Canon PowerShot SD500
# 10919  Canon PowerShot SD500
#
#                                      review_preprocessed  \
# 0      [(excellent, JJ), (phone, NN), (, NNP), (excel...
# 1      [(business, NN), (user, VBD), (heavily, RB), (...
# 2      [(much, RB), (say, VBD), (reviews, JJ), (featu...
# 3      [(double, RB), (check, VB), (customer, NN), (s...
# 4      [(several, JJ), (year, NNS), (torture, JJ), (h...
# ...                                                  ...
# 10915  [(many, JJ), (time, NNS), (click, VBD), (autom...
# 10916  [(seem, VBZ), (double, JJ), (click, JJ), (time...
# 10917  [(huh, NN), (, NNS), (miss, VBD), (lot, NNS), ...
# 10918  [(control, NNS), (hard, JJ), (manipulate, NN),...
# 10919  [(lcd, NN), (screen, NN), (small, JJ), (since,...
#
#                                            opinion_words
# 0                             {'service': ['excellent']}
# 1                                {'service': ['mobile']}
# 2      {'feature': ['reviews', 'great'], 'problem': [...
# 3                                 {'number': ['amazon']}
# 4                              {'customer': ['torture']}
# ...                                                  ...
# 10915                                                 {}
# 10916                                                 {}
# 10917                                {'lot': ['blurry']}
# 10918                                                 {}
# 10919                      {'screen': ['small', 'many']}
#
# [10920 rows x 3 columns]

# %% [markdown]
# # 2. Extract Relevant Information

# %% [markdown]
# Here I need to do two algorithms and see what the results are. ABSA or whatever it's called and then one unsupervised approach

# %% [markdown]
# # 3. Report Evaluation results
